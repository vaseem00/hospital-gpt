# %%
from bs4 import BeautifulSoup
import requests

url = 'https://hospitals.webometrics.info/en/world'

# Send a GET request to the webpage
response = requests.get(url)
# Assuming `html_content` is the HTML source code you've posted.
soup = BeautifulSoup(response.text, 'html.parser')

# Find the table by its class name.
table = soup.find('table', class_="sticky-enabled")

# Find all the rows in the table body, skipping the header row.
rows = table.find('tbody').find_all('tr')

# Create a list to hold all hospital data.
hospitals = []

# Loop through all the rows and get the text from each cell.
for row in rows:
    # Get all columns in the row.
    cols = row.find_all('td')
    website = cols[1].find('a')['href']
    # Extract text from each column using list comprehension.
    hospital_data = [col.text.strip() for col in cols]
    # Add a dictionary of the data to the hospitals list (optional).
    hospitals.append([
        hospital_data[1],
        
        website,
        
    ])

# Now you have a list of dictionaries with the data.
for hospital in hospitals:
    print(hospital)
# Out:
# ['Cleveland Clinic', 'http://my.clevelandclinic.org/']
# ["St Jude Children's Research Hospital", 'http://www.stjude.org/']
# ['Johns Hopkins Medicine', 'http://www.hopkinsmedicine.org/']
# ['Mayo Clinic Scottsdale AZ', 'http://www.mayoclinic.org/']
# ['University of Maryland Medical Center', 'http://umm.edu/']
# ['M D Anderson Cancer Center', 'http://www.mdanderson.org/']
# ['Massachusetts General Hospital', 'http://www.massgeneral.org/']
# ['Assistance Publique Hôpitaux de Paris', 'http://www.aphp.fr/']
# ['Memorial Sloan Kettering Cancer Center', 'http://www.mskcc.org/']
# ['New York Presbyterian / Lower Manhattan Hospital', 'http://nyp.org/']
# ['Providence Health & Services', 'https://www2.providence.org/']
# ["Deer's Head Hospital Center", 'http://dhmh.maryland.gov/']
# ['Buddhist Tzu Chi General Hospital', 'http://www.tzuchi.com.tw/']
# ['Beth Israel Deaconess Medical Center Needham', 'http://www.bidmc.org/']
# ['Aurora Health Care', 'http://www.aurorahealthcare.org/']
# ['Taipei Veterans General Hospital', 'http://www.vghtpe.gov.tw/']
# ['Advocate Health Care', 'http://www.advocatehealth.com/']
# ['University of Pittsburgh Medical Center', 'http://www.upmc.com/']
# ["Brigham and Women's Hospital", 'http://www.brighamandwomens.org/']
# ['(1)  Hartford Hospital', 'http://www.harthosp.org/']
# ['INCA Instituto Nacional de Câncer', 'http://www2.inca.gov.br/']
# ['University Clinic Heidelberg Universittsklinikum Heidelberg', 'http://www.klinikum.uni-heidelberg.de/']
# ['Erasmus Medisch Centrum Universitait Medisch Centrum Rotterdam', 'http://www.erasmusmc.nl/']
# ['Asklepios Klinikum Bad Abbach', 'http://www.asklepios.com/']
# ['Xinqiao Hospital Third Military Medical University', 'http://www.xqhospital.com.cn/']
# ['Alberta Health Services', 'http://www.albertahealthservices.ca/']
# ['Tricare Military Health System', 'https://www.tricare.mil/']
# ['National Taiwan University Hospital', 'http://www.ntuh.gov.tw/']
# ["Children's Hospital of Philadelphia", 'http://www.chop.edu/']
# ['H Lee Moffitt Cancer Center & Research Institute', 'http://moffitt.org/']
# ['Navy Medicine', 'http://www.med.navy.mil/']
# ["Children's Mercy Hospitals and Clinics", 'http://www.childrensmercy.org/']
# ['Jilin University Bethune Hospital - First Hospital of Jilin University', 'http://www.jdyy.cn/']
# ['Leiden University Medical Center / Leids Universitair Medisch Centrum', 'http://www.lumc.nl/']
# ['Centre Hospitalier Universitaire Vaudois Lausanne', 'http://www.chuv.ch/']
# ['Arizona State Hospital', 'http://www.azdhs.gov/']
# ['Hôpitaux Universitaires de Geneve', 'http://www.hug-ge.ch/']
# ['Universitätsklinikum Hamburg Eppendorf', 'http://www.uke.de/']
# ['Hospital Authority', 'http://www.ha.org.hk/']
# ['Universitätsklinikum und Medizinische Fakultät Tübingen', 'http://www.medizin.uni-tuebingen.de/']
# ['Sahlgrenska University Hospital', 'http://www.sahlgrenska.se/']
# ['Kaiser Permanente CA', 'http://healthy.kaiserpermanente.org/']
# ['National Hospital Organization', 'http://www.hosp.go.jp/']
# ['University of North Carolina Healthcare', 'http://www.unchealthcare.org/']
# ['University of Wisconsin Health', 'http://www.uwhealth.org/']
# ['Universitätsklinikum Freiburg', 'http://www.uniklinik-freiburg.de/']
# ["Seattle Children's Hospital and Medical Center", 'http://www.seattlechildrens.org/']
# ['University of Chicago Hospitals', 'http://www.uchospitals.edu/']
# ['Universitätsklinikum Jena Klinikum der Friedrich Schiller Universität', 'http://www.uniklinikum-jena.de/']
# ['Klinik und Poliklinik für Hals Nasen Ohrenheilkunde Ludwig Maximilians Universität München', 'http://www.klinikum.uni-muenchen.de/']
# ["Children's Hospital Boston", 'http://www.childrenshospital.org/']
# ['Society of Cardiovascular and Interventional Radiology', 'http://www.sirweb.org/']
# ["Royal Children's Hospital", 'http://www.rch.org.au/']
# ['Peking Union Medical College Hospital Beijing', 'http://www.pumch.cn/']
# ['(1)  University of Virginia Health System', 'http://www.healthsystem.virginia.edu/']
# ['Texas Health Resources Inc.', 'http://www.texashealth.org/']
# ['Instytut Psychiatrii i Neurologii', 'http://www.ipin.edu.pl/']
# ["Cincinnati Children's Hospital Medical Center", 'http://www.cincinnatichildrens.org/']
# ['Hospital Israelita Albert Einstein', 'http://www.einstein.br/']
# ['Northwestern Medicine', 'http://www.nm.org/']
# ['Ochsner Health System', 'http://www.ochsner.org/']
# ['Mount Sinai Medical Center New York', 'http://www.mountsinai.org/']
# ['Universitair Ziekenhuis Leuven', 'http://www.uzleuven.be/']
# ['University of Utah Health Care', 'http://healthcare.utah.edu/']
# ['UniverstätsSpitals Zürich', 'http://www.usz.ch/']
# ['Hirslanden Privatklinikgruppe', 'http://www.hirslanden.ch/']
# ['Royal Berkshire NHS Foundation Trust', 'http://www.royalberkshire.nhs.uk/']
# ['(1)  Inselspital Universitatsspital Bern', 'http://www.insel.ch/']
# ['Lahey Clinic', 'http://www.lahey.org/']
# ['Beijing Hospital', 'http://www.bjhmoh.cn/']
# ['Group Health Cooperative Health Care System Seattle', 'http://www.ghc.org/']
# ['Partners Healthcare System', 'http://www.partners.org/']
# ['Carolinas Healthcare System', 'http://www.carolinashealthcare.org/']
# ['Henry Ford Hospital', 'http://www.henryford.com/']
# ['UCLA University of California Los Angeles Health System CA', 'http://www.uclahealth.org/']
# ['King Faisal Specialist Hospital & Research Centre', 'http://www.kfshrc.edu.sa/']
# ['Hospital Italiano de Buenos Aires', 'http://www.hospitalitaliano.org.ar/']
# ['Klinikum der Johannes Gutenberg Universität Mainz', 'http://www.unimedizin-mainz.de/']
# ['Vu Medical Center Amsterdam', 'http://www.vumc.nl/']
# ["Children's Healthcare of Atlanta Pediatric Hospital", 'http://www.choa.org/']
# ['Hospital El Cruce', 'http://www.hospitalelcruce.org/']
# ['Inova Health System Northern Virginia', 'http://www.inova.org/']
# ['Universitätsklinikum Magdeburg', 'http://www.med.uni-magdeburg.de/']
# ['Banner Health', 'http://www.bannerhealth.com/']
# ["Guy's and St Thomas' Hospital NHS", 'http://www.guysandstthomas.nhs.uk/']
# ['Peacehealth', 'http://www.peacehealth.org/']
# ['Intermountain Healthcare ID', 'http://intermountainhealthcare.org/']
# ['Universitair Medisch Centrum Groningen', 'http://www.umcg.nl/']
# ['Mercy', 'http://www.mercy.net/']
# ['L’Institut Curie', 'http://curie.fr/']
# ['Indiana University Health Bloomington', 'http://iuhealth.org/']
# ['Hospital for Special Surgery', 'http://www.hss.edu/']
# ['Universitätsklinikum Dusseldorf', 'http://www.uniklinik-duesseldorf.de/']
# ['Centre Hospitalier Universitaire de Lyon hôpitaux de Lyon', 'http://www.chu-lyon.fr/']
# ['Rigshospitalet', 'http://www.rigshospitalet.dk/']
# ['Sanford Health (Union Hospital Mayville North Dakota)', 'http://www.sanfordhealth.org/']
# ['Uniklinik Köln - Klinikum der Universitat Zu Köln', 'http://www.uk-koeln.de/']
# ['Hospital for Sick Children', 'http://www.sickkids.ca/']
# ['Dana Farber Cancer Institute Boston MA', 'http://www.dana-farber.org/']
# ['Norrbottens Lans Landsting', 'http://www.nll.se/']

# %%
import pandas as pd

df = pd.DataFrame(columns = ['hospital_name', 'link'])
for i in hospitals:
    length = len(df)
    df.loc[length]= i
#df.to_csv(r'/Users/user/Desktop/ml-project/hospitals.csv', index = False)

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse, urljoin
import pandas as pd

def is_valid_url(url):
    """
    Checks if a given URL is valid and not an external link.
    """
    parsed_url = urlparse(url)
    return bool(parsed_url.netloc) and bool(parsed_url.scheme)

def get_all_website_links(url, domain_name):
    """
    Returns all URLs that are found on a website in which the domain name matches the domain name of the main URL.
    """
    urls = set()
    queue = [url]
    while queue:
        current_url = queue.pop(0)
        try:
            response = requests.get(current_url, timeout=10)
            soup = BeautifulSoup(response.content, 'html.parser')
            for a_tag in soup.findAll("a"):
                href = a_tag.attrs.get("href")
                if href == "" or href is None:
                    # href empty tag
                    continue
                href = urljoin(current_url, href)
                parsed_href = urlparse(href)
                href = parsed_href.scheme + "://" + parsed_href.netloc + parsed_href.path
                if not is_valid_url(href):
                    # not a valid URL
                    continue
                if domain_name not in href:
                    # external link
                    continue
                if href in urls:
                    continue
                urls.add(href)
                queue.append(href)
        except Exception as e:
            print(f"Error: {e}")
            continue
    return urls

def scrape_hospital_info(url):
    domain_name = urlparse(url).netloc
    all_links = get_all_website_links(url, domain_name)
    
    # Example of how you might process each page
    for link in all_links:
        response = requests.get(link)
        # You can add your scraping logic here, similar to the single-page example
    
# Example: Scraping for one hospital - you'll need to loop through your list for all hospitals
scrape_hospital_info("http://www.albertahealthservices.ca/")
'ok'

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse, urljoin
import pandas as pd

# Initialize a session
session = requests.Session()
session.headers.update({'User-Agent': 'Custom User Agent'})

def scrape_site(url):
    """
    Scrape information from a hospital website starting with the given URL.
    This is a simplified example that primarily looks for contact information as a demonstration.
    """
    visited_urls = set()
    to_visit_urls = [url]

    hospital_info = {
        "Hospital Name": None,
        "Location (City)": None,
        "Location (State/Province)": None,
        "Location (Country)": None,
        "Contact Phone": None,
        "Website": url,
        "Email": None,
        "Number of Beds": None,
        "Specialties": None,
        "Awards/Accreditations": None,
        "Ranking": None,
        "Services": None,
        "Focus Areas": None,
        "Mission Statement": None,
        "History": None,
        "Doctor Names": None
    }

    while to_visit_urls:
        current_url = to_visit_urls.pop(0)
        if current_url in visited_urls:
            continue

        try:
            response = session.get(current_url)
            soup = BeautifulSoup(response.content, 'html.parser')

            # Example: Looking for contact info
            # You would add specific logic here to extract the information of interest
            # This might include searching for specific tags, classes, or IDs that match what you're looking for

            visited_urls.add(current_url)

            # Find all links on page and add them to to_visit_urls if they match criteria
            for link in soup.find_all('a', href=True):
                href = link['href']
                full_url = urljoin(current_url, href)
                if urlparse(full_url).hostname == urlparse(url).hostname:
                    to_visit_urls.append(full_url)

        except requests.RequestException as e:
            print(f"Request failed for {current_url}: {e}")

    return hospital_info

# Replace 'your_hospital_website_here' with the actual hospital website URL
hospital_website = 'http://my.clevelandclinic.org/'
info = scrape_site(hospital_website)
print(info)
